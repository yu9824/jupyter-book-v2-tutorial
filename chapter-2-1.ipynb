# %% [markdown]
# # Chapter 2-1

# %%
print("Chapter 2-1")
# Out:
# Chapter 2-1

# %% [markdown]
# ```yaml
# toc:
# - title: Chapter 2  # indexなくてもOK
#   children:
#   - file: chapter-2-1.ipynb
# ```
